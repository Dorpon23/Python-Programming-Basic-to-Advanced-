# %%
import pandas
df = pandas.read_csv("C:\\Users\\Dorpon\\Python\\annual-enterprise-survey-2019-financial-year-provisional-csv.csv")
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
from bs4 import BeautifulSoup

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '10. More on Functions.ipynb',
#  '11. File Processing.ipynb',
#  '12. Imported Modules.ipynb',
#  '13. Application 1 Build an Interactive English Dictionary.ipynb',
#  '14. Project Exercise with Python and MySQL Interactive English Dictionary.ipynb',
#  '15. Data Analysis with Pandas.ipynb',
#  '3. The Basics Data Types.ipynb',
#  '4. The Basics Operations with Data Types.ipynb',
#  '5. The Basics Functions and Conditionals.ipynb',
#  '6. The Basics Processing User Input.ipynb',
#  '7. The Basics Loops.ipynb',
#  '8. Putting the Pieces Together Building a Program.ipynb',
#  '9. List Comprehensions.ipynb',
#  'annual-enterprise-survey-2019-financial-year-provisional-csv.csv',
#  'data.json',
#  'export_dataframe.csv',
#  'First_Program.ipynb',
#  'fruits.txt',
#  'Run.txt',
#  'supermarket(data).txt',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
# ...

# %%
df1= pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt")
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
pandas.read_csv?

# %%
df6 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df6
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = pandas.read_csv("supermarket(data).txt",header= None)
df7
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df7.columns = ["ID","Address","City","Zip","Country","Name","Employee"]
df7
# Out:
#    ID          Address           City               Zip Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
df7.set_index("ID")
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employee
# ID
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df8=df7.set_index("ID")

# %%
df8
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employee
# ID
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df7.set_index("ID", inplace = True)
df7
# Out:
#             Address           City               Zip Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employee
# ID
# 1          8
# 2         15
# 3         25
# 4         10
# 5         12
# 6         20

# %%
df7.set_index("Address", inplace = True)
df7
# Out:
#                           City               Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employee
# Address
# 3666 21st St            8
# 735 Dolores St         15
# 332 Hill St            25
# 3995 23rd St           10
# 1056 Sanchez St        12
# 551 Alvarado St        20

# %%
df7.set_index("Name", inplace = False, drop = False)
df7
# Out:
#                           City               Zip Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employee
# Address
# 3666 21st St            8
# 735 Dolores St         15
# 332 Hill St            25
# 3995 23rd St           10
# 1056 Sanchez St        12
# 551 Alvarado St        20

# %%
df9 = pandas.read_json("supermarkets.json")
df9.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df9.loc["0":"2","Address":"Name"]
# Out:
#           Address           City             State Country         Name
# 0    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2     332 Hill St  San Francisco  California 94114     USA  Super River

# %%
df9.loc[:,"Country"]
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# Name: Country, dtype: object

# %%
list(df9.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9.iloc[0:3,0:4]
# Out:
#    ID         Address           City             State
# 0   1    3666 21st St  San Francisco          CA 94114
# 1   2  735 Dolores St  San Francisco          CA 94119
# 2   3     332 Hill St  San Francisco  California 94114

# %%
df9.iloc[0:4,2:4]
# Out:
#             City             State
# 0  San Francisco          CA 94114
# 1  San Francisco          CA 94119
# 2  San Francisco  California 94114
# 3  San Francisco          CA 94114

# %%
df9.iloc[4,0:4]
# Out:
# ID                       5
# Address    1056 Sanchez St
# City         San Francisco
# State           California
# Name: 4, dtype: object

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(12).reshape(3, 4),
                  columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
#Column based delete
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
##Column based delete
df.drop(columns=['B', 'C'])
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
#Row based delete
df.drop([0, 1])
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %%
df10=df9.set_index("ID")
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df10.drop("Address",1)
# Out:
#              City             State Country         Name  Employees
# ID
# 1   San Francisco          CA 94114     USA      Madeira          8
# 2   San Francisco          CA 94119     USA  Bready Shop         15
# 3   San Francisco  California 94114     USA  Super River         25
# 4   San Francisco          CA 94114     USA   Ben's Shop         10
# 5   San Francisco        California     USA      Sanchez         12
# 6   San Francisco          CA 94114     USA   Richvalley         20

# %%
df10.drop(["Country","Employees"],1)
# Out:
#             Address           City             State         Name
# ID
# 1      3666 21st St  San Francisco          CA 94114      Madeira
# 2    735 Dolores St  San Francisco          CA 94119  Bready Shop
# 3       332 Hill St  San Francisco  California 94114  Super River
# 4      3995 23rd St  San Francisco          CA 94114   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114   Richvalley

# %%
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df10.drop([1, 2],0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df10.drop("1056 Sanchez St",1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-eab09c58929f> in <module>
# ----> 1 df10.drop("1056 Sanchez St",1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df10.drop(df10.index[0:3],1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-b9c13954dea4> in <module>
# ----> 1 df10.drop(df10.index[0:3],1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df10.drop(df10.columns[0:4],1)
# Out:
#            Name  Employees
# ID
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df10.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
df10.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
len(df10.index)
# Out:
# 6

# %%
df10.shape
# Out:
# (6, 6)

# %%
df10.shape[1]
# Out:
# 6

# %%
df10["Continent"]= df10.shape[0]*["North America"]

# %%
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df10["Continent"]= df10["Country"]+ ", " +["North America"]
df10
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees           Continent
# ID
# 1           8  USA, North America
# 2          15  USA, North America
# 3          25  USA, North America
# 4          10  USA, North America
# 5          12  USA, North America
# 6          20  USA, North America

# %%
df10_t = df10.T
df10_t
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df10_t[7]=["Bohorompoor","Rajshahi","Rajshahi 234","Bangladesh","Dorpon",10,"Bangladesh,East Asia"]

# %%
df10_t
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  USA, North America  USA, North America  USA, North America
#
# ID                          4                   5                   6  \
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# City            San Francisco       San Francisco       San Francisco
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# ...

# %%
df_update=df10_t.transpose()
df_update
# Out:
#             Address           City             State     Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119         USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114         USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114         USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California         USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114         USA   Richvalley
# 7       Bohorompoor       Rajshahi      Rajshahi 234  Bangladesh       Dorpon
#
#    Employees             Continent
# ID
# 1          8    USA, North America
# 2         15    USA, North America
# 3         25    USA, North America
# 4         10    USA, North America
# 5         12    USA, North America
# 6         20    USA, North America
# 7         10  Bangladesh,East Asia

# %%
import geopy
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
 from geopy.geocoders import Nominatim
        
geopy.geocoders.options.default_user_agent = "abc"

# %%
nom=Nominatim()

# %%
n=nom.geocode("rajshahi city college, Bangladesh")

# %%
nom.geocode("3995 23rd st, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, San Francisco, San Francisco City and County, California, 94114, United States, (37.7529648, -122.4317141, 0.0))

# %%
n.latitude
# Out:
# 24.4611511

# %%
 n.longitude
# Out:
# 88.6888703

# %%
type(n)
# Out:
# geopy.location.Location

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"]+", "+df["City"]+", "+df["State"]+", "+df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] =df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates
# Out:
# 0    (3666, 21st Street, Noe Valley, San Francisco,...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, San Francisco, ...
# 3    (3995, 23rd Street, Noe Valley, San Francisco,...
# 4    (1056;1058;1060;1062, Sanchez Street, Noe Vall...
# 5    (551, Alvarado Street, Noe Valley, San Francis...
# Name: Coordinates, dtype: object

# %%
df.Coordinates[0].latitude
# Out:
# 37.75664965

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x:x.latitude)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x:x.latitude if x!=None else None)
df["Longititude"] = df["Coordinates"].apply(lambda x:x.longitude if x!=None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude  Longititude
# ...
